# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjitaPrajapati/AI4CCEE_Fall_2024/blob/main/in_class_activity/lecture4/Submissions/sanjita_lecture4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Activity 0

# %%
import pandas as pd
data_path = '/content/Wavetronix.csv'
sensor_data = pd.read_csv(data_path)
sensor_data.head()
# Out:
#    day                 Time  WAVE-NE-Count  WAVE-NE-Speed  WAVE-SW-Count  \
# 0    1  2022-07-10 00:00:00            NaN            NaN            3.0
# 1    1  2022-07-10 00:01:00           10.0           62.0            2.0
# 2    1  2022-07-10 00:02:00            5.0           63.6            4.0
# 3    1  2022-07-10 00:03:00           11.0           58.2            9.0
# 4    1  2022-07-10 00:04:00           19.0           60.2           17.0
#
#    WAVE-SW-Speed  Month  Year
# 0           59.5     10  2021
# 1           59.0     10  2021
# 2           58.4     10  2021
# 3           60.0     10  2021
# 4           61.2     10  2021

# %%
import matplotlib.pyplot as plt
sensor_data['Time'] = pd.to_datetime(sensor_data['Time'])
plt.figure(figsize=(14, 7))
plt.plot(sensor_data['Time'], sensor_data['WAVE-NE-Speed'], label='WAVE-NE-Speed', color='blue')
plt.title('Speed vs. Time for Northeast Direction')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
speed_threshold = 20
below_threshold = sensor_data['WAVE-NE-Speed'] < speed_threshold
plt.scatter(sensor_data['Time'][below_threshold], sensor_data['WAVE-NE-Speed'][below_threshold],
            color='red', label='Below Threshold Speed')
num_events = below_threshold.sum()
plt.legend()
plt.show()
num_events
# Out:
# 5

# %%
day_1_data_ne = sensor_data[sensor_data['day'] == 1]
day_1_data_ne['Smoothed_NE_Speed_Day1'] = day_1_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()
plt.figure(figsize=(14, 7))
plt.plot(day_1_data_ne['Time'], day_1_data_ne['Smoothed_NE_Speed_Day1'], label='Smoothed NE Speed - Day 1', color='blue')
plt.title('Smoothed Speed vs. Time for Northeast Direction on Day 1')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-4-3bab63512916>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_1_data_ne['Smoothed_NE_Speed_Day1'] = day_1_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()

# %%
day_2_data_ne = sensor_data[sensor_data['day'] == 2]
day_2_data_ne['Smoothed_NE_Speed_Day2'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()
plt.figure(figsize=(14, 7))
plt.plot(day_2_data_ne['Time'], day_2_data_ne['Smoothed_NE_Speed_Day2'], label='Smoothed NE Speed - Day 2', color='blue')
plt.title('Smoothed Speed vs. Time for Northeast Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-5-ae3389f387da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_2_data_ne['Smoothed_NE_Speed_Day2'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()

# %%
day_3_data_ne = sensor_data[sensor_data['day'] == 3]
day_3_data_ne['Smoothed_NE_Speed_Day3'] = day_3_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()
plt.figure(figsize=(14, 7))
plt.plot(day_3_data_ne['Time'], day_3_data_ne['Smoothed_NE_Speed_Day3'], label='Smoothed NE Speed - Day 3', color='blue')
plt.title('Smoothed Speed vs. Time for Northeast Direction on Day 3')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-6-447f552a28a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_3_data_ne['Smoothed_NE_Speed_Day3'] = day_3_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()

# %%
plt.figure(figsize=(14, 7))
plt.scatter(day_2_data_ne['Time'], day_2_data_ne['Smoothed_NE_Speed_Day2'], color='blue', label='Smoothed NE Speed - Day 2', s=10)
plt.title('Smoothed Speed vs. Time for Northeast Direction on Day 2 (Scatter Plot)')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()

# %%
speed_below_60 = day_2_data_ne['Smoothed_NE_Speed_Day2'] < 60
speed_at_or_above_60 = day_2_data_ne['Smoothed_NE_Speed_Day2'] >= 60
plt.figure(figsize=(14, 7))
plt.scatter(day_2_data_ne['Time'][speed_below_60], day_2_data_ne['Smoothed_NE_Speed_Day2'][speed_below_60],
            color='red', label='Speed < 60', s=10)
plt.scatter(day_2_data_ne['Time'][speed_at_or_above_60], day_2_data_ne['Smoothed_NE_Speed_Day2'][speed_at_or_above_60],
            color='blue', label='Speed >= 60', s=10)
plt.title('Classified Speed vs. Time for Northeast Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Activity 1

# %%
day_2_data_ne['5min_Rolling_Avg'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=5, min_periods=1).mean()
plt.figure(figsize=(14, 7))
plt.plot(day_2_data_ne['Time'], day_2_data_ne['WAVE-NE-Speed'], label='Original NE Speed - Day 2', color='red', alpha=0.5)
plt.plot(day_2_data_ne['Time'], day_2_data_ne['5min_Rolling_Avg'], label='5-Min Rolling Avg - Day 2', color='blue')
plt.title('Comparison of Original and Smoothed Speed Data for NE Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-9-e47a85a15663>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_2_data_ne['5min_Rolling_Avg'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=5, min_periods=1).mean()

# %%
plt.figure(figsize=(14, 7))
plt.scatter(day_2_data_ne['Time'], day_2_data_ne['WAVE-NE-Speed'], color='red', alpha=0.5, label='Original NE Speed - Day 2', s=10)
plt.scatter(day_2_data_ne['Time'], day_2_data_ne['5min_Rolling_Avg'], color='blue', label='5-Min Rolling Avg - Day 2', s=10)
plt.title('Scatter Plot Comparison of Original and Smoothed Speed Data for NE Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.scatter(day_2_data_ne['Time'], day_2_data_ne['WAVE-NE-Speed'], color='red', alpha=0.5, label='Original NE Speed - Day 2', s=10)
# Create the 10-minute rolling average column
day_2_data_ne['10min_Rolling_Avg'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()
plt.scatter(day_2_data_ne['Time'], day_2_data_ne['10min_Rolling_Avg'], color='blue', label='10-Min Rolling Avg - Day 2', s=10)
plt.title('Scatter Plot Comparison of Original and 10-Minute Smoothed Speed Data for NE Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-11-2bb72a8712cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_2_data_ne['10min_Rolling_Avg'] = day_2_data_ne['WAVE-NE-Speed'].rolling(window=10, min_periods=1).mean()

# %% [markdown]
# Activity 2

# %%
missing_values = day_2_data_ne['WAVE-NE-Speed'].isnull().sum()
if missing_values > 0:
    day_2_data_ne['WAVE-NE-Speed'].interpolate(inplace=True)
day_2_data_ne.drop_duplicates(subset=['Time'], inplace=True)
day_2_data_ne = day_2_data_ne[(day_2_data_ne['WAVE-NE-Speed'] >= 0) & (day_2_data_ne['WAVE-NE-Speed'] <= 120)]
preprocessing_results = {
    "Missing Values": missing_values,
    "Duplicates Removed": not day_2_data_ne.duplicated(['Time']).any(),
    "Unreasonable Values Filtered": not ((day_2_data_ne['WAVE-NE-Speed'] < 0) | (day_2_data_ne['WAVE-NE-Speed'] > 120)).any()
}
preprocessing_results
# Out:
# <ipython-input-12-8fa0de1f4679>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   day_2_data_ne['WAVE-NE-Speed'].interpolate(inplace=True)
# <ipython-input-12-8fa0de1f4679>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_2_data_ne['WAVE-NE-Speed'].interpolate(inplace=True)
# ...

# %%
plt.figure(figsize=(14, 7))
plt.plot(day_2_data_ne['Time'], day_2_data_ne['WAVE-NE-Speed'], label='Cleaned NE Speed - Day 2', color='blue')
plt.title('Cleaned Speed Data for NE Direction on Day 2')
plt.xlabel('Time')
plt.ylabel('Speed (units)')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
fft_values = np.fft.fft(day_2_data_ne['WAVE-NE-Speed'])
frequencies = np.fft.fftfreq(len(fft_values), d=1)  # d is the sampling period (1 minute)
fft_magnitude = np.abs(fft_values)
plt.figure(figsize=(14, 7))
plt.stem(frequencies, fft_magnitude, 'b', markerfmt=" ", basefmt="-b")
plt.title('Frequency Spectrum of Cleaned NE Speed Data on Day 2')
plt.xlabel('Frequency (cycles per minute)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %%
# !pip install PyWavelets
import matplotlib.pyplot as plt
import numpy as np

import pywt # This line imports the PyWavelets module, which provides the 'pywt' functions.
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.0 MB/s eta 0:00:00
# ...

# %%
# use 'list' to get a list of all available 1d demo signals
signals = pywt.data.demo_signal('list')

subplots_per_fig = 5
signal_length = 1024
i_fig = 0
n_figures = int(np.ceil(len(signals)/subplots_per_fig))
for i_fig in range(n_figures):
    # Select a subset of functions for the current plot
    func_subset = signals[
        i_fig * subplots_per_fig:(i_fig + 1) * subplots_per_fig]

    # create a figure to hold this subset of the functions
    fig, axes = plt.subplots(subplots_per_fig, 1)
    axes = axes.ravel()
    for n, signal in enumerate(func_subset):
        if signal in ['Gabor', 'sineoneoverx']:
            # user cannot specify a length for these two
            x = pywt.data.demo_signal(signal)
        else:
            x = pywt.data.demo_signal(signal, signal_length)
        ax = axes[n]
        ax.plot(x.real)
        if signal == 'Gabor':
            # The Gabor signal is complex-valued
            ax.plot(x.imag)
            ax.legend(['Gabor (Re)', 'Gabor (Im)'], loc='upper left')
        else:
            ax.legend([signal, ], loc='upper left')
    # omit axes for any unused subplots
    for n in range(n + 1, len(axes)):
        axes[n].set_axis_off()
plt.show()

# %%
#!/usr/bin/env python

import matplotlib.pyplot as plt
import numpy as np

import pywt

time, sst = pywt.data.nino()
dt = time[1] - time[0]

wavelet = 'cmor1.5-1.0'
scales = np.arange(1, 128)

[cfs, frequencies] = pywt.cwt(sst, scales, wavelet, dt)
power = (abs(cfs)) ** 2

period = 1. / frequencies
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8]
f, ax = plt.subplots(figsize=(15, 10))
ax.contourf(time, np.log2(period), np.log2(power), np.log2(levels),
            extend='both')

ax.set_title(f'Nino1+2 Wavelet Power Spectrum ({wavelet})')
ax.set_ylabel('Period (years)')
Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())),
                        np.ceil(np.log2(period.max())))
ax.set_yticks(np.log2(Yticks))
ax.set_yticklabels(Yticks)
ax.invert_yaxis()
ylim = ax.get_ylim()
ax.set_ylim(ylim[0], -1)

plt.show()

# %% [markdown]
# Activity 3

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt

# %%
# Extract the WAVE-NE-Speed column for the analysis
signal =  day_2_data_ne['WAVE-NE-Speed'].values

# Define scales (these control the resolution of the wavelet transform)
scales = np.arange(1, 128)

# Apply the CWT with the 'mexh' wavelet
coefficients, frequencies = pywt.cwt(signal, scales, 'mexh')

# %%
plt.figure(figsize=(10, 6))

# Create a heatmap of the wavelet coefficients
plt.imshow(np.abs(coefficients), extent=[0, len(signal), 1, 128], cmap='jet', aspect='auto',
           vmax=np.percentile(np.abs(coefficients), 99))  # Adjust the color scale for visibility

plt.colorbar(label='Magnitude of Coefficients')
plt.title('Scalogram of WAVE-NE-Speed (Wavelet: Mexican Hat)')
plt.xlabel('Time')
plt.ylabel('Scale')
plt.show()

# %% [markdown]
# Activity 4

# %%
# !pip install requests Pillow PyWavelets

# %%
import requests

# URL of the image
url = 'https://github.com/barkham21/ai4ccee_fall_2024/blob/main/in_class_activity/lecture4/2018-06-30-19-05.jpg?raw=true'

# Send a GET request to the URL and save the image
response = requests.get(url)
with open('image.jpg', 'wb') as file:
    file.write(response.content)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
img = Image.open('image.jpg')

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import numpy as np

# Convert the image to grayscale (optional, you can also work with color)
img_gray = img.convert('L')

# Convert to NumPy array
img_array = np.array(img_gray)

# %%
import pywt

# Perform 2D Discrete Wavelet Transform using the 'haar' wavelet
coeffs2 = pywt.dwt2(img_array, 'haar')

# Unpack the coefficients (LL: Approximation, LH: Horizontal, HL: Vertical, HH: Diagonal)
LL, (LH, HL, HH) = coeffs2

# %%
plt.figure(figsize=(12, 8))

# Plot the approximation coefficients (LL)
plt.subplot(2, 2, 1)
plt.imshow(LL, cmap='gray')
plt.title('Approximation (LL)')
plt.axis('off')

# Plot the horizontal detail coefficients (LH)
plt.subplot(2, 2, 2)
plt.imshow(LH, cmap='gray')
plt.title('Horizontal Details (LH)')
plt.axis('off')

# Plot the vertical detail coefficients (HL)
plt.subplot(2, 2, 3)
plt.imshow(HL, cmap='gray')
plt.title('Vertical Details (HL)')
plt.axis('off')

# Plot the diagonal detail coefficients (HH)
plt.subplot(2, 2, 4)
plt.imshow(HH, cmap='gray')
plt.title('Diagonal Details (HH)')
plt.axis('off')

plt.tight_layout()
plt.show()
