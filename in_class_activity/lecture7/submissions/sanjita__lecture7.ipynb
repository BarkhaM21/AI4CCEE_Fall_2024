# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjitaPrajapati/AI4CCEE_Fall_2024/blob/main/in_class_activity/lecture7/submissions/sanjita__lecture7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Activity 2 - Filtering

# %% [markdown]
# ![Screenshot from 2024-10-24 13-06-25.png](data:image/png;base64,...)

# %% [markdown]
# # Activity 3 - Aggregations

# %% [markdown]
# ![Screenshot from 2024-10-24 13-13-12.png](data:image/png;base64,...)

# %% [markdown]
# # Activity 4 - Joins

# %% [markdown]
# ![Screenshot from 2024-10-24 13-19-25.png](data:image/png;base64,...)

# %% [markdown]
# # Activity 5 - Nested Queries

# %% [markdown]
# ![Screenshot from 2024-11-06 13-17-34.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2024-11-06 13-19-18.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2024-11-06 13-19-59.png](data:image/png;base64,...)
