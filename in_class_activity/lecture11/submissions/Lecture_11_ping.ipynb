# %% [markdown]
# <a href="https://colab.research.google.com/github/pingisu/AI4CCEE_Fall_2024/blob/main/in_class_activity/lecture11/submissions/Lecture_11_ping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Import the datasets module from tensorflow.keras. This will allow you to load the CIFAR-10 dataset.

# !pip install tensorflow

from tensorflow.keras.datasets import cifar10

# %%
# prompt: Use the datasets.cifar10.load_data() method to download and load the CIFAR-10 dataset.

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# prompt: Assign the result to two tuples: (train_images, train_labels) for the training data. (test_images, test_labels) for the testing data.

train_images, train_labels = x_train, y_train
test_images, test_labels = x_test, y_test

# %%
# prompt: Pixel values in the CIFAR-10 images range from 0 to 255. Normalize these values to a range of 0 to 1 to improve model performance.

import numpy as np

# Normalize pixel values to be between 0 and 1
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
# prompt: Divide both train_images and tPixel values in the CIFAR-10 images range from 0 to 255. Normalize these values to a range of 0 to 1 to improve model performance.

# No further code is needed as the provided code already normalizes the pixel values.
# The code you provided already normalizes train_images and test_images by dividing by 255.0.

# %%
# prompt: Divide both train_images and test_images by 255.0. Update their values directly.

train_images /= 255.0
test_images /= 255.0

# %%
# prompt: Verify the download process.

from tensorflow.keras.datasets import cifar10
import numpy as np

# The following line is not needed if the library is already installed in the environment.
# If you are running this in a new environment, uncomment the line below.
#!pip install tensorflow


(x_train, y_train), (x_test, y_test) = cifar10.load_data()

train_images, train_labels = x_train, y_train
test_images, test_labels = x_test, y_test

# Normalize pixel values to be between 0 and 1
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Verify the normalization
print("Min value in train_images:", train_images.min())
print("Max value in train_images:", train_images.max())
print("Min value in test_images:", test_images.min())
print("Max value in test_images:", test_images.max())

#Check the shapes of the data
print("Shape of train_images:", train_images.shape)
print("Shape of train_labels:", train_labels.shape)
print("Shape of test_images:", test_images.shape)
print("Shape of test_labels:", test_labels.shape)
# Out:
# Min value in train_images: 0.0
# Max value in train_images: 1.0
# Min value in test_images: 0.0
# Max value in test_images: 1.0
# Shape of train_images: (50000, 32, 32, 3)
# Shape of train_labels: (50000, 1)
# Shape of test_images: (10000, 32, 32, 3)
# Shape of test_labels: (10000, 1)

# %%
# prompt: Import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Assuming train_images, train_labels, test_images, and test_labels are already defined and normalized.

# Display the first 25 images from the training set with their labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i][0])  # Assuming labels are in the format [[label], [label], ...]
plt.show()

# %%
# prompt: Create a list named class_names containing the names of the classes. These should correspond to the classes in the dataset, such as = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck’]

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# prompt: Use plt.figure() to create a figure for the plot. Set its size to 10x10 using the figsize parameter.

# Assuming train_images, train_labels, test_images, and test_labels are already defined and normalized.

# Display the first 25 images from the training set with their labels
plt.figure(figsize=(10, 10)) #This line is already present in the provided code.
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])  # Use class_names for labels
plt.show()

# %%
# prompt: Loop through the first 25 images Using a for loop with a range of 25. This will help in plotting 25 images (from 0 to 24).

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Assuming train_images, train_labels, test_images, and test_labels are already defined and normalized.

# Display the first 25 images from the training set with their labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])  # Removed cmap, as it's not needed for color images
    plt.xlabel(class_names[train_labels[i][0]])  # Use class_names for labels
plt.show()

# %%
# prompt: Create a subplot for each image. Inside the loop, use plt.subplot(rows, cols, index) to create a grid layout of 5 rows and 5 columns. Use i+1 as the index to position each image correctly in the grid.

# Assuming train_images, train_labels, and class_names are already defined and normalized.

# Display the first 25 images from the training set with their labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])  # Removed cmap, as it's not needed for color images
    plt.xlabel(class_names[train_labels[i][0]])  # Use class_names for labels
plt.show()

# %%
# prompt: Remove axis ticks and grid:
# For a clean visual appearance, use plt.xticks([]) and plt.yticks([]) to remove ticks from both axes.
# Use plt.grid(False) to disable the grid.

# Assuming train_images, train_labels, and class_names are already defined and normalized.

# Display the first 25 images from the training set with their labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])  # Removed cmap, as it's not needed for color images
    plt.xlabel(class_names[train_labels[i][0]])  # Use class_names for labels
plt.show()
